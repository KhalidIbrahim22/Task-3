# %% [markdown]
# ![picture.jpg](attachment:picture.jpg)

# %% [markdown]
# # Author: Khalid Ibrahim

# %% [markdown]
# ###### The Sparks Foundation: Data Science & Business Analytics Internship

# %% [markdown]
# ## Task 3 : Exploratory Data Analysis - Retail (Level - Beginner)

# %% [markdown]
# ###### Problem Statement:

# %% [markdown]
# As a business manager, try to find out the weak areas where you can work to make more profit.

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# ## Importing packages

# %%
import pandas as pd

# %% [markdown]
# ## Importing the data

# %%
df=pd.read_csv("SampleSuperstore.csv")

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
def missing_percentage(df):
    total = df.isnull().sum().sort_values(ascending = False)[df.isnull().sum().sort_values(ascending = False)!= 0]
    percent = round(df.isnull().sum().sort_values(ascending = False)/len(df)*100 , 2)[round(df.isnull().sum().sort_values(ascending = False)/len(df)*100 , 2)!= 0]
    data_type = df.dtypes.sort_values(ascending = False)[df.isnull().sum().sort_values(ascending = False)!= 0]
    return pd.concat([total , percent , data_type],axis = 1 , keys = ['Total' , 'Percent' , 'Type'])

# %%
missing_percentage(df)
# Out:
# Empty DataFrame
# Columns: [Total, Percent, Type]
# Index: []

# %%
#There are no null values

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# ## Data Analysis

# %% [markdown]
#  - Why are there negative profits?
#  - How to decrease them as possible ?

# %%
negative_profit = df[df['Profit']<=0]

# %%
negative_profit
# Out:
#            Ship Mode      Segment        Country             City  \
# 3     Standard Class     Consumer  United States  Fort Lauderdale
# 14    Standard Class  Home Office  United States       Fort Worth
# 15    Standard Class  Home Office  United States       Fort Worth
# 23      Second Class     Consumer  United States     Philadelphia
# 27    Standard Class     Consumer  United States     Philadelphia
# ...              ...          ...            ...              ...
# 9921  Standard Class  Home Office  United States            Akron
# 9931  Standard Class     Consumer  United States   San Bernardino
# 9937    Second Class    Corporate  United States      Los Angeles
# 9962     First Class  Home Office  United States          Houston
# 9977  Standard Class  Home Office  United States      Los Angeles
#
#              State  Postal Code   Region         Category Sub-Category  \
# 3          Florida        33311    South        Furniture       Tables
# ...

# %%
negative_profit.to_csv("Negative_profit.csv")

# %% [markdown]
# .

# %%
positive_profit = df[df['Profit']>0]

# %%
positive_profit
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5     Standard Class   Consumer  United States      Los Angeles  California
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
positive_profit.to_csv("Positive_profit.csv")

# %% [markdown]
# .

# %% [markdown]
# # Insights

# %% [markdown]
# With a quick look at the data you can clearly see huge difference in "Discount" between positive and negative profits

# %% [markdown]
#  .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# Does more dicount means more Sales ?

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# After viewing the data we can tell that more discounts doesn't mean more sales

# %% [markdown]
# ### So my suggestion to increase profit will be to get rid of any discount that is more than 20%
